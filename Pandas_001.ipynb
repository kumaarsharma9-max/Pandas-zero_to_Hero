# %% [markdown]
# ###**Pandas Tutorial**

# %% [markdown]
# **Pandas (stands for Python Data Analysis) is an open-source software library designed for data manipulation and analysis.**
#
# *  **Built on top of NumPy, efficiently manages large datasets, offering tools for data cleaning, transformation and analysis.**<br>
#
# *  **Seamlessly integrates with other Python libraries like NumPy, Matplotlib and scikit-learn.**<br>
#
# *  **Revolves around two primary Data structures: Series (1D) and DataFrame (2D)**
# **Provides methods like .dropna() and .fillna() to handle missing values  seamlessly**<br>
#
# *   **pandas_basic_operations.webppandas_basic_operations.webp**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**What is Pandas Used for?**

# %% [markdown]
#   **1. Reading and writing data from various file formats like CSV, Excel and SQL databases.**
#
#   **2. Cleaning and preparing data (handling missing values, filtering, removing duplicates).**
#
#   **3. Merging, joining, and reshaping datasets.**
#
#   **4. Performing statistical analysis and descriptive statistics.**
#
#   **5. Visualizing data quickly.**

# %% [markdown]
# **Pandas Introduction**

# %% [markdown]
# **Pandas is an open-source Python library used for data manipulation, analysis and cleaning. It provides fast and flexible tools to work with tabular data, similar to spreadsheets or SQL tables.**
#
# **Pandas is used in data science, machine learning, finance, analytics and automation because it integrates smoothly with other libraries such as:**

# %% [markdown]
# *  **NumPy: numerical operations**
#
# *  **Matplotlib and Seaborn: data visualization**
#
# *  **SciPy: statistical analysis**
#
# *  **Scikit-learn: machine learning workflows**

# %% [markdown]
# ###**Data Structures in Pandas**

# %% [markdown]
# ###**1. Pandas Series**

# %% [markdown]
# **A Pandas Series is one-dimensional labeled array capable of holding data of any type (integer, string, float, Python objects etc.). The axis labels are collectively called indexes.**
#
# **Series is created by loading the datasets from existing storage which can be a SQL database, a CSV file or an Excel file.**

# %% [markdown]
# **Installation**

# %%
import numpy as np
import pandas as pd

s = pd.Series()
print("pandas Series: ",s)
data = np.array(['K','u','m','a','a','r'])

s = pd.Series(data)
print("Pandas Series:\n", s)

# %% [markdown]
# ### **2. Pandas DataFrame**

# %% [markdown]
# **Pandas DataFrame is a two-dimensional data structure with labeled axes (rows and columns).**<br>
#
# **It is created by loading the datasets from existing storage which can be a SQL database, a CSV file or an Excel file. It can be created from lists, dictionaries, a list of dictionaries etc.**

# %%
import pandas as pd

df = pd.DataFrame()
print(df)
list_ = ['Deep learning', 'models', 'are', 'specialized', 'neural network','architectures', 'designed to process complex data types']

df = pd.DataFrame(list_)
print(df)
